# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#Read the image
img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/bird2.jpg")
img = cv2. resize(img, (400, 400))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F1E843C7650>

# %%
gray_image=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F1E843D6C90>

# %%
#invert the image
inverted_gray_image=255 - gray_image
cv2_imshow(inverted_gray_image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F1E843C7DD0>

# %%
#blur the image 
blurred_image =cv2.GaussianBlur(inverted_gray_image,(21,21),0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F1E843C7790>

# %%
#invert the blur image
inverted_blur_img=255-blurred_image
cv2_imshow(inverted_blur_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F1E843EF890>

# %%
#pencil sketch
penciil_img=cv2.divide(gray_image,inverted_blur_img,scale=256.0)
cv2_imshow(penciil_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F1E843E8890>
